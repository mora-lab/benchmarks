# %% [markdown]
# # Enrichr Results Compilation

# %% [markdown]
# Importing necessary packages, loading library segments, and setting up data for the benchmark dataset.

# %%
### Sourcing tools from GEO ###
    
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")
    
BiocManager::install("GenomicRanges")
BiocManager::install("rtracklayer")
BiocManager::install("usethis")
library(GenomicRanges)
library(rtracklayer)
library(usethis)
    
### Installing package dependencies ###
    
BiocManager::install("devtools")
BiocManager::install("roxygen2")
library(devtools)
library(roxygen2)

# %%
ChIPSeqDataMaster <- read.table(file = "/Users/mei/Desktop/benchmarks/genomic_range/data/GSA_ChIP_Seq_Master_Table.txt", sep = '\t', header = TRUE, quote = "")

# %%
## The following code creates a list of samples for which we need to extract the BED files for.
    
ChIPSeqSamples<-as.character(ChIPSeqDataMaster$GSM)
    
## Initializing list for storing BED files and the consecutive GRanges objects.
Samples_in_BED = list()
    
for(i in 1:length(ChIPSeqSamples))
    {
      Samples_in_BED[[i]] <- read.table(paste0("/Users/mei/LabWork/GSAChIPSeqBenchmarkDataBase/regen/",paste0(eval(parse(text="ChIPSeqSamples[i]")),".bed")), sep = "\t", header = FALSE)
      Samples_in_BED[[i]] <- Samples_in_BED[[i]][,1:3]
      colnames(Samples_in_BED[[i]]) <- c("chrom", "start", "end")
      Samples_in_BED[[i]] <- Samples_in_BED[[i]][order(Samples_in_BED[[i]]$chrom),]
      Samples_in_BED[[i]] <- GRanges(Samples_in_BED[[i]]$chrom, IRanges(Samples_in_BED[[i]]$`start`, Samples_in_BED[[i]]$`end`))
      genome(Samples_in_BED[[i]]) <- "hg19"
    }
    
## Saving BED files as GRanges objects ##
names(Samples_in_BED) <- ChIPSeqSamples

# %% [markdown]
# ## GO Results

# %% [markdown]
# The results from Enrichr were manually curated for the samples from the benchmark dataset and stored at distinct locations for KEGG and GO enrichments; the folders were named **KEGG_2016** and **GO_BP_2016**, respectively. The code has been sourced from **Enrichr_Results_Compilaton.R** and **Enrichr_Preprocessing.R** functions available at https://github.com/mora-lab/benchmarks/tree/master/genomic_range/R.

# %%
tryCatch( {enrichr_go_samples <- read.table("/Users/mei/LabWork/GSAChIPSeqBenchmarkDataBase/Results/enrichr/GO_BP_2018/file_names.txt")}
          ,error = function(e){ print("File not found"); break;}
          ,finally = function (f){next;})

# %%
class(enrichr_go_samples)
# Out:
# [1] "data.frame"

# %%
head(enrichr_go_samples)
# Out:
#   V1
# 1 GSE84618.txt
# 2 GSM1847178.txt
# 3 GSM2058015.txt
# 4 GSM2058016.txt
# 5 GSM2058017.txt
# 6 GSM2058018.txt

# %% [markdown]
# As you can see here, **enrichr_go_samples** is a dataframe with one column holding the samples whose corresponding results are placed in the folder. We want to extract these results. For doing so, we shall begin with pruning the file names by removing extension- *.txt*.

# %%
enrichr_go_samples <- as.character(enrichr_go_samples$V1)
for(i in 1:length(enrichr_go_samples)){enrichr_go_samples[i] <- substr(enrichr_go_samples[i],1,nchar(enrichr_go_samples[i])-4)}

# %%
head(enrichr_go_samples)
# Out:
# [1] "GSE84618"   "GSM1847178" "GSM2058015" "GSM2058016" "GSM2058017"
# [6] "GSM2058018"

# %% [markdown]
# Now that we have the precise sample labels, let us define a list **enrichr_go** that shall hold the enrichr results (dataframe), for each sample.

# %%
enrichr_go <- list()

for (i in 1: length(ChIPSeqSamples))
{
  for(j in 1:length(enrichr_go_samples))
  {
    if(enrichr_go_samples[j] == ChIPSeqSamples[i])
    {
      enrichr_go[[j]] <-read.table(paste0("/Users/mei/LabWork/GSAChIPSeqBenchmarkDataBase/Results/enrichr/GO_BP_2018/",paste0(eval(parse(text='ChIPSeqSamples[i]')),".txt")), sep = '\t', header = TRUE, quote = "", fill = TRUE)
    }
  }
}

# %%
class(enrichr_go)
# Out:
# [1] "list"

# %% [markdown]
# So, eventually **enrichr_go** is a list of dataframes.

# %%
head(enrichr_go[[1]])
# Out:
#   Term
# 1 regulation of skeletal muscle contraction (GO:0014819)
# 2 cell-cell junction maintenance (GO:0045217)
# 3 regulation of transforming growth factor beta2 production (GO:0032909)
# 4 regulation of histone H3-K9 acetylation (GO:2000615)
# 5 regulation of Golgi organization (GO:1903358)
# 6 chondroitin sulfate catabolic process (GO:0030207)
#   Overlap P.value      Adjusted.P.value Old.P.value  Old.Adjusted.P.value
# 1 3/7     0.0037479580 0.9441197        0.0052339067 0.7605585
# 2 4/11    0.0015450556 0.9441197        0.0019520713 0.7605585
# 3 2/7     0.0443520949 0.9441197        0.0427839212 0.7605585
# 4 3/8     0.0057748139 0.9441197        0.0069970387 0.7605585
# 5 5/15    0.0006100561 0.9441197        0.0007217959 0.7605585
# 6 4/14    0.0041556430 0.9441197        0.0040004439 0.7605585
#   Z.score   Combined.Score Genes
# 1 -3.158475 17.64496       CAV3;DMPK;KCNJ2
# 2 -2.577299 16.68207       CAMSAP3;NLGN2;PLEKHA7;CD177
# 3 -4.395784 13.69548       SMAD4;CDH3
# 4 -2.630837 13.55999       SMAD4;CHEK1;BRCA1
# 5 -1.822244 13.48818       CAMSAP3;MAP2K1;STX18;RBSN;MAPK3
# 6 -2.408644 13.20729       BCAN;HYAL1;NCAN;ARSB

# %% [markdown]
# We observe an element from the list, and see that it outputs quite a bit og information. Following the scope of our analysis, we shall only require the **Term** and **P.value** parameters. So, the remaining columns are filtered out.

# %%
enrichr_go_results <- list()
for (i in 1:length(enrichr_go))
{
  enrichr_go_results[[i]] <- enrichr_go[[i]][,c(1,3)]
}

names(enrichr_go_results) <- as.character(enrichr_go_samples)

# %% [markdown]
# ## KEGG Results

# %% [markdown]
# We shall follow the exact same protocol for KEGG results as well.

# %%
## Same protocol for ENRICHR KEGG results too. 


enrichr_kegg <- list()

enrichr_kegg_samples <- read.table("/Users/mei/LabWork/GSAChIPSeqBenchmarkDataBase/Results/enrichr/KEGG_2016/file_names.txt")
enrichr_kegg_samples <- as.character(enrichr_kegg_samples$V1)
for(i in 1:length(enrichr_kegg_samples)){enrichr_kegg_samples[i] <- substr(enrichr_kegg_samples[i],1,nchar(enrichr_kegg_samples[i])-4)}



enrichr_kegg <- list()

for (i in 1: length(ChIPSeqSamples))
{
  for(j in 1:length(enrichr_kegg_samples))
  {
    if(enrichr_kegg_samples[j] == ChIPSeqSamples[i])
    {
      enrichr_kegg[[j]] <-read.table(paste0("/Users/mei/LabWork/GSAChIPSeqBenchmarkDataBase/Results/enrichr/KEGG_2016/",paste0(eval(parse(text='ChIPSeqSamples[i]')),".txt")), sep = '\t', header = TRUE, quote = "", fill = TRUE)
    }
  }
}


## Condensed Results

enrichr_kegg_results <- list()
for (i in 1:length(enrichr_kegg))
{
  enrichr_kegg_results[[i]] <- enrichr_kegg[[i]][,c(1,3)]
}

names(enrichr_kegg_results) <- as.character(enrichr_kegg_samples)

# %% [markdown]
# Now that we have the individual enrichment results from GO and KEGG ontologies, we shall proceed with combining the results for each sample to engender a consolidated set. Prior to that, let's check if the sample count is consistent for both cohorts.

# %%
# for consistency with Chipenrich, Broadenrich, Seq2pathway results' variable nomenclature.
enrichr_go_results_shredded <- enrichr_go_results
enrichr_kegg_results_shredded <- enrichr_kegg_results

count <- 0
for (i in 1:length(names(enrichr_go_results_shredded)))
{
  for(j in 1:length(names(enrichr_kegg_results_shredded)))
  {
    if(names(enrichr_go_results_shredded)[i] == names(enrichr_kegg_results_shredded)[j])
    {
      count <- count+1
    }
  }
}
print (count)
# Out:
# [1] 106

# %% [markdown]
# Cool ! That shows that we have results from  both KEGG and GO for all samples; number of samples in our benchmark dataset is 106.

# %%
## Refining Enrichr KEGG and GO results | Extracting "hsa*****" and "GO:*****" terms.
#install.packages("stringr", repos = "https://mirrors.tuna.tsinghua.edu.cn/CRAN/")
BiocManager::install("stringr")
library(stringr)
enrichr_go_terms_extracted_results_shredded <- list()
enrichr_go_terms_extracted_results_shredded <- enrichr_go_results_shredded
for (i in 1:length(enrichr_go_results_shredded))
{
  enrichr_go_terms_extracted_results_shredded[[i]]$Term <- str_extract(string = print(eval(parse(text=paste0("enrichr_go_results_shredded$",paste0(eval(parse(text="names(enrichr_go_results_shredded)[i]")),"$Term"))))), pattern = "GO:[0-9]+")
}

enrichr_kegg_terms_extracted_results_shredded <- list()
enrichr_kegg_terms_extracted_results_shredded <- enrichr_kegg_results_shredded
for (i in 1:length(enrichr_kegg_results_shredded))
{
  enrichr_kegg_terms_extracted_results_shredded[[i]]$Term <- str_extract(string = print(eval(parse(text=paste0("enrichr_kegg_results_shredded$",paste0(eval(parse(text="names(enrichr_kegg_results_shredded)[i]")),"$Term"))))), pattern = "hsa[0-9]+")
}
# Out:
# Bioconductor version 3.8 (BiocManager 1.30.4), R 3.5.2 (2018-12-20)
# Installing package(s) 'stringr'
# The downloaded binary packages are in
# 	/var/folders/hm/c3_fjypn62v5xh5b5ygv267m0000gn/T//RtmpxWUpqS/downloaded_packages
# Update old packages: 'callr', 'checkmate', 'deSolve', 'digest', 'dplyr',
#   'ellipsis', 'emmeans', 'gam', 'git2r', 'haven', 'lavaan', 'mclust', 'pillar',
#   'plotmo', 'processx', 'quantreg', 'recipes', 'remotes', 'rlang', 'rngtools',
#   'robust', 'sf', 'tinytex', 'vdiffr', 'xfun'
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#   [1] Oxytocin signaling pathway_Homo sapiens_hsa04921
#   [2] Aldosterone synthesis and secretion_Homo sapiens_hsa04925
#   [3] Acute myeloid leukemia_Homo sapiens_hsa05221
#   [4] Oocyte meiosis_Homo sapiens_hsa04114
#   [5] Gastric acid secretion_Homo sapiens_hsa04971
#   [6] Long-term potentiation_Homo sapiens_hsa04720
#   [7] Inflammatory mediator regulation of TRP channels_Homo sapiens_hsa04750
#   [8] Adrenergic signaling in cardiomyocytes_Homo sapiens_hsa04261
#   [9] Vascular smooth muscle contraction_Homo sapiens_hsa04270
#  [10] Salivary secretion_Homo sapiens_hsa04970
#  [11] Long-term depression_Homo sapiens_hsa04730
#  [12] beta-Alanine metabolism_Homo sapiens_hsa00410
#  [13] Endocrine and other factor-regulated calcium reabsorption_Homo sapiens_hsa04961
#  [14] Progesterone-mediated oocyte maturation_Homo sapiens_hsa04914
#  [15] Citrate cycle (TCA cycle)_Homo sapiens_hsa00020
#  [16] Phenylalanine metabolism_Homo sapiens_hsa00360
#  [17] Estrogen signaling pathway_Homo sapiens_hsa04915
#  [18] 2-Oxocarboxylic acid metabolism_Homo sapiens_hsa01210
#  [19] Lysine degradation_Homo sapiens_hsa00310
#  [20] Sphingolipid signaling pathway_Homo sapiens_hsa04071
#  [21] Thyroid hormone synthesis_Homo sapiens_hsa04918
#  [22] Ribosome biogenesis in eukaryotes_Homo sapiens_hsa03008
#  [23] Rap1 signaling pathway_Homo sapiens_hsa04015
#  [24] GnRH signaling pathway_Homo sapiens_hsa04912
#  [25] Pentose and glucuronate interconversions_Homo sapiens_hsa00040
#  [26] Gap junction_Homo sapiens_hsa04540
#  [27] Wnt signaling pathway_Homo sapiens_hsa04310
#  [28] Cholinergic synapse_Homo sapiens_hsa04725
#  [29] Circadian entrainment_Homo sapiens_hsa04713
#  [30] cGMP-PKG signaling pathway_Homo sapiens_hsa04022
#  [31] Glycerolipid metabolism_Homo sapiens_hsa00561
#  [32] VEGF signaling pathway_Homo sapiens_hsa04370
#  [33] Melanogenesis_Homo sapiens_hsa04916
#  [34] Complement and coagulation cascades_Homo sapiens_hsa04610
#  [35] Retrograde endocannabinoid signaling_Homo sapiens_hsa04723
#  [36] Neurotrophin signaling pathway_Homo sapiens_hsa04722
#  [37] Ubiquitin mediated proteolysis_Homo sapiens_hsa04120
#  [38] Calcium signaling pathway_Homo sapiens_hsa04020
#  [39] TGF-beta signaling pathway_Homo sapiens_hsa04350
#  [40] Renin secretion_Homo sapiens_hsa04924
#  [41] Pancreatic cancer_Homo sapiens_hsa05212
#  [42] Hypertrophic cardiomyopathy (HCM)_Homo sapiens_hsa05410
#  [43] Platelet activation_Homo sapiens_hsa04611
#  [44] HIF-1 signaling pathway_Homo sapiens_hsa04066
#  [45] Hepatitis B_Homo sapiens_hsa05161
#  [46] Dorso-ventral axis formation_Homo sapiens_hsa04320
#  [47] Glycosphingolipid biosynthesis - lacto and neolacto series_Homo sapiens_hsa00601
#  [48] Dilated cardiomyopathy_Homo sapiens_hsa05414
#  [49] Morphine addiction_Homo sapiens_hsa05032
#  [50] mRNA surveillance pathway_Homo sapiens_hsa03015
#  [51] Alzheimer's disease_Homo sapiens_hsa05010
#  [52] Purine metabolism_Homo sapiens_hsa00230
#  [53] Glycerophospholipid metabolism_Homo sapiens_hsa00564
#  [54] Small cell lung cancer_Homo sapiens_hsa05222
#  [55] RNA transport_Homo sapiens_hsa03013
#  [56] Transcriptional misregulation in cancer_Homo sapiens_hsa05202
#  [57] Ascorbate and aldarate metabolism_Homo sapiens_hsa00053
#  [58] Leukocyte transendothelial migration_Homo sapiens_hsa04670
#  [59] Olfactory transduction_Homo sapiens_hsa04740
#  [60] Viral carcinogenesis_Homo sapiens_hsa05203
#  [61] Antigen processing and presentation_Homo sapiens_hsa04612
#  [62] Systemic lupus erythematosus_Homo sapiens_hsa05322
#  [63] Influenza A_Homo sapiens_hsa05164
#  [64] Hippo signaling pathway_Homo sapiens_hsa04390
#  [65] Metabolic pathways_Homo sapiens_hsa01100
#  [66] Jak-STAT signaling pathway_Homo sapiens_hsa04630
#  [67] NF-kappa B signaling pathway_Homo sapiens_hsa04064
#  [68] Metabolism of xenobiotics by cytochrome P450_Homo sapiens_hsa00980
#  [69] Longevity regulating pathway - mammal_Homo sapiens_hsa04211
#  [70] Alcoholism_Homo sapiens_hsa05034
#  [71] Tuberculosis_Homo sapiens_hsa05152
#  [72] Carbon metabolism_Homo sapiens_hsa01200
#  [73] MAPK signaling pathway_Homo sapiens_hsa04010
#  [74] Arginine and proline metabolism_Homo sapiens_hsa00330
#  [75] Cytosolic DNA-sensing pathway_Homo sapiens_hsa04623
#  [76] Aminoacyl-tRNA biosynthesis_Homo sapiens_hsa00970
#  [77] Protein processing in endoplasmic reticulum_Homo sapiens_hsa04141
#  [78] Cell adhesion molecules (CAMs)_Homo sapiens_hsa04514
#  [79] Tight junction_Homo sapiens_hsa04530
#  [80] Adherens junction_Homo sapiens_hsa04520
#  [81] AGE-RAGE signaling pathway in diabetic complications_Homo sapiens_hsa04933
#  [82] Measles_Homo sapiens_hsa05162
#  [83] Spliceosome_Homo sapiens_hsa03040
#  [84] Natural killer cell mediated cytotoxicity_Homo sapiens_hsa04650
#  [85] Biosynthesis of amino acids_Homo sapiens_hsa01230
#  [86] Galactose metabolism_Homo sapiens_hsa00052
#  [87] Vibrio cholerae infection_Homo sapiens_hsa05110
#  [88] Phagosome_Homo sapiens_hsa04145
#  [89] MicroRNAs in cancer_Homo sapiens_hsa05206
#  [90] Phosphatidylinositol signaling system_Homo sapiens_hsa04070
#  [91] Pyrimidine metabolism_Homo sapiens_hsa00240
#  [92] Pertussis_Homo sapiens_hsa05133
#  [93] Choline metabolism in cancer_Homo sapiens_hsa05231
#  [94] Cell cycle_Homo sapiens_hsa04110
#  [95] Chagas disease (American trypanosomiasis)_Homo sapiens_hsa05142
#  [96] Signaling pathways regulating pluripotency of stem cells_Homo sapiens_hsa04550
#  [97] Chemokine signaling pathway_Homo sapiens_hsa04062
#  [98] Insulin signaling pathway_Homo sapiens_hsa04910
#  [99] Toxoplasmosis_Homo sapiens_hsa05145
# [100] Non-small cell lung cancer_Homo sapiens_hsa05223
# [101] Epstein-Barr virus infection_Homo sapiens_hsa05169
# [102] PI3K-Akt signaling pathway_Homo sapiens_hsa04151
# [103] Cytokine-cytokine receptor interaction_Homo sapiens_hsa04060
# [104] FoxO signaling pathway_Homo sapiens_hsa04068
# [105] Ovarian steroidogenesis_Homo sapiens_hsa04913
# [106] Huntington's disease_Homo sapiens_hsa05016
# [107] Bile secretion_Homo sapiens_hsa04976
# [108] TNF signaling pathway_Homo sapiens_hsa04668
# [109] Neuroactive ligand-receptor interaction_Homo sapiens_hsa04080
# [110] cAMP signaling pathway_Homo sapiens_hsa04024
# [111] Apoptosis_Homo sapiens_hsa04210
# [112] Pathways in cancer_Homo sapiens_hsa05200
# [113] Cocaine addiction_Homo sapiens_hsa05030
# [114] Proteoglycans in cancer_Homo sapiens_hsa05205
# [115] Notch signaling pathway_Homo sapiens_hsa04330
# [116] Regulation of actin cytoskeleton_Homo sapiens_hsa04810
# [117] Prostate cancer_Homo sapiens_hsa05215
# [118] AMPK signaling pathway_Homo sapiens_hsa04152
# [119] PPAR signaling pathway_Homo sapiens_hsa03320
# [120] Phospholipase D signaling pathway_Homo sapiens_hsa04072
# [121] Amino sugar and nucleotide sugar metabolism_Homo sapiens_hsa00520
# [122] Hematopoietic cell lineage_Homo sapiens_hsa04640
# [123] Parkinson's disease_Homo sapiens_hsa05012
# [124] Protein digestion and absorption_Homo sapiens_hsa04974
# [125] Herpes simplex infection_Homo sapiens_hsa05168
# [126] Endocytosis_Homo sapiens_hsa04144
# [127] Fatty acid metabolism_Homo sapiens_hsa01212
# [128] Glutathione metabolism_Homo sapiens_hsa00480
# [129] Insulin secretion_Homo sapiens_hsa04911
# [130] Fc epsilon RI signaling pathway_Homo sapiens_hsa04664
# [131] Lysosome_Homo sapiens_hsa04142
# [132] T cell receptor signaling pathway_Homo sapiens_hsa04660
# [133] Non-alcoholic fatty liver disease (NAFLD)_Homo sapiens_hsa04932
# [134] HTLV-I infection_Homo sapiens_hsa05166
# [135] Focal adhesion_Homo sapiens_hsa04510
# [136] Ras signaling pathway_Homo sapiens_hsa04014
# [137] Nucleotide excision repair_Homo sapiens_hsa03420
# [138] Thyroid hormone signaling pathway_Homo sapiens_hsa04919
# [139] Salmonella infection_Homo sapiens_hsa05132
# [140] Ribosome_Homo sapiens_hsa03010
# [141] Epithelial cell signaling in Helicobacter pylori infection_Homo sapiens_hsa05120
# [142] Fc gamma R-mediated phagocytosis_Homo sapiens_hsa04666
# [143] Axon guidance_Homo sapiens_hsa04360
# [144] Amphetamine addiction_Homo sapiens_hsa05031
# [145] Sphingolipid metabolism_Homo sapiens_hsa00600
# [146] Dopaminergic synapse_Homo sapiens_hsa04728
# [147] Carbohydrate digestion and absorption_Homo sapiens_hsa04973
# [148] NOD-like receptor signaling pathway_Homo sapiens_hsa04621
# [149] Osteoclast differentiation_Homo sapiens_hsa04380
# [150] Hepatitis C_Homo sapiens_hsa05160
# [151] GABAergic synapse_Homo sapiens_hsa04727
# [152] Glucagon signaling pathway_Homo sapiens_hsa04922
# [153] Toll-like receptor signaling pathway_Homo sapiens_hsa04620
# [154] Insulin resistance_Homo sapiens_hsa04931
# [155] Ether lipid metabolism_Homo sapiens_hsa00565
# [156] Pancreatic secretion_Homo sapiens_hsa04972
# [157] Oxidative phosphorylation_Homo sapiens_hsa00190
# [158] Amoebiasis_Homo sapiens_hsa05146
# [159] ECM-receptor interaction_Homo sapiens_hsa04512
# [160] Glutamatergic synapse_Homo sapiens_hsa04724
# [161] Cysteine and methionine metabolism_Homo sapiens_hsa00270
# [162] mTOR signaling pathway_Homo sapiens_hsa04150
# [163] Inflammatory bowel disease (IBD)_Homo sapiens_hsa05321
# [164] Serotonergic synapse_Homo sapiens_hsa04726
# [165] Other types of O-glycan biosynthesis_Homo sapiens_hsa00514
# [166] Bacterial invasion of epithelial cells_Homo sapiens_hsa05100
# [167] Chronic myeloid leukemia_Homo sapiens_hsa05220
# [168] ErbB signaling pathway_Homo sapiens_hsa04012
# [169] B cell receptor signaling pathway_Homo sapiens_hsa04662
# [170] Mucin type O-Glycan biosynthesis_Homo sapiens_hsa00512
# [171] Taste transduction_Homo sapiens_hsa04742
# [172] Rheumatoid arthritis_Homo sapiens_hsa05323
# [173] Prolactin signaling pathway_Homo sapiens_hsa04917
# [174] Glioma_Homo sapiens_hsa05214
# [175] Central carbon metabolism in cancer_Homo sapiens_hsa05230
# [176] Renal cell carcinoma_Homo sapiens_hsa05211
# [177] Chemical carcinogenesis_Homo sapiens_hsa05204
# [178] Peroxisome_Homo sapiens_hsa04146
# [179] RNA degradation_Homo sapiens_hsa03018
# [180] Arachidonic acid metabolism_Homo sapiens_hsa00590
# [181] Adipocytokine signaling pathway_Homo sapiens_hsa04920
# [182] Cardiac muscle contraction_Homo sapiens_hsa04260
# [183] Fat digestion and absorption_Homo sapiens_hsa04975
# [184] Leishmaniasis_Homo sapiens_hsa05140
# [185] Regulation of lipolysis in adipocytes_Homo sapiens_hsa04923
# [186] Viral myocarditis_Homo sapiens_hsa05416
# [187] Nicotine addiction_Homo sapiens_hsa05033
# [188] p53 signaling pathway_Homo sapiens_hsa04115
# [189] Arrhythmogenic right ventricular cardiomyopathy (ARVC)_Homo sapiens_hsa05412
# [190] Melanoma_Homo sapiens_hsa05218
# [191] Staphylococcus aureus infection_Homo sapiens_hsa05150
# [192] Inositol phosphate metabolism_Homo sapiens_hsa00562
# [193] RIG-I-like receptor signaling pathway_Homo sapiens_hsa04622
# [194] Basal cell carcinoma_Homo sapiens_hsa05217
# [195] Drug metabolism - cytochrome P450_Homo sapiens_hsa00982
# [196] Longevity regulating pathway - multiple species_Homo sapiens_hsa04213
# [197] Starch and sucrose metabolism_Homo sapiens_hsa00500
# [198] Retinol metabolism_Homo sapiens_hsa00830
# [199] Shigellosis_Homo sapiens_hsa05131
# [200] Glycolysis / Gluconeogenesis_Homo sapiens_hsa00010
# [201] Colorectal cancer_Homo sapiens_hsa05210
# [202] Synaptic vesicle cycle_Homo sapiens_hsa04721
# [203] Endometrial cancer_Homo sapiens_hsa05213
# [204] Legionellosis_Homo sapiens_hsa05134
# [205] Tyrosine metabolism_Homo sapiens_hsa00350
# [206] Steroid hormone biosynthesis_Homo sapiens_hsa00140
# [207] Pathogenic Escherichia coli infection_Homo sapiens_hsa05130
# [208] DNA replication_Homo sapiens_hsa03030
# [209] Bladder cancer_Homo sapiens_hsa05219
# [210] Fanconi anemia pathway_Homo sapiens_hsa03460
# [211] Type II diabetes mellitus_Homo sapiens_hsa04930
# [212] Hedgehog signaling pathway_Homo sapiens_hsa04340
# [213] Base excision repair_Homo sapiens_hsa03410
# [214] N-Glycan biosynthesis_Homo sapiens_hsa00510
# [215] Asthma_Homo sapiens_hsa05310
# [216] Fructose and mannose metabolism_Homo sapiens_hsa00051
# [217] Valine, leucine and isoleucine degradation_Homo sapiens_hsa00280
# [218] Tryptophan metabolism_Homo sapiens_hsa00380
# [219] Pentose phosphate pathway_Homo sapiens_hsa00030
# [220] Glycine, serine and threonine metabolism_Homo sapiens_hsa00260
# [221] Fatty acid degradation_Homo sapiens_hsa00071
# [222] Proteasome_Homo sapiens_hsa03050
# [223] Drug metabolism - other enzymes_Homo sapiens_hsa00983
# [224] Pyruvate metabolism_Homo sapiens_hsa00620
# [225] Linoleic acid metabolism_Homo sapiens_hsa00591
# [226] ABC transporters_Homo sapiens_hsa02010
# [227] Aldosterone-regulated sodium reabsorption_Homo sapiens_hsa04960
# [228] Homologous recombination_Homo sapiens_hsa03440
# [229] Porphyrin and chlorophyll metabolism_Homo sapiens_hsa00860
# [230] Primary immunodeficiency_Homo sapiens_hsa05340
# [231] Glycosaminoglycan biosynthesis - keratan sulfate_Homo sapiens_hsa00533
# [232] African trypanosomiasis_Homo sapiens_hsa05143
# [233] Prion diseases_Homo sapiens_hsa05020
# [234] Thyroid cancer_Homo sapiens_hsa05216
# [235] Regulation of autophagy_Homo sapiens_hsa04140
# [236] Phototransduction_Homo sapiens_hsa04744
# [237] Alanine, aspartate and glutamate metabolism_Homo sapiens_hsa00250
# [238] SNARE interactions in vesicular transport_Homo sapiens_hsa04130
# [239] Glyoxylate and dicarboxylate metabolism_Homo sapiens_hsa00630
# [240] Circadian rhythm_Homo sapiens_hsa04710
# [241] Mismatch repair_Homo sapiens_hsa03430
# [242] Glycosaminoglycan biosynthesis - chondroitin sulfate / dermatan sulfate_Homo sapiens_hsa00532
# [243] Collecting duct acid secretion_Homo sapiens_hsa04966
# [244] One carbon pool by folate_Homo sapiens_hsa00670
# [245] Histidine metabolism_Homo sapiens_hsa00340
# [246] Vitamin digestion and absorption_Homo sapiens_hsa04977
# [247] Glycosaminoglycan degradation_Homo sapiens_hsa00531
# [248] Arginine biosynthesis_Homo sapiens_hsa00220
# [249] Other glycan degradation_Homo sapiens_hsa00511
# [250] Selenocompound metabolism_Homo sapiens_hsa00450
# [251] Folate biosynthesis_Homo sapiens_hsa00790
# [252] Phenylalanine, tyrosine and tryptophan biosynthesis_Homo sapiens_hsa00400
# 252 Levels: 2-Oxocarboxylic acid metabolism_Homo sapiens_hsa01210 ...
#   [1] Glyoxylate and dicarboxylate metabolism_Homo sapiens_hsa00630
#   [2] Amphetamine addiction_Homo sapiens_hsa05031
#   [3] Long-term potentiation_Homo sapiens_hsa04720
#   [4] Sulfur metabolism_Homo sapiens_hsa00920
#   [5] PPAR signaling pathway_Homo sapiens_hsa03320
#   [6] Tight junction_Homo sapiens_hsa04530
#   [7] Arrhythmogenic right ventricular cardiomyopathy (ARVC)_Homo sapiens_hsa05412
#   [8] Glycosaminoglycan biosynthesis - heparan sulfate / heparin_Homo sapiens_hsa00534
#   [9] mRNA surveillance pathway_Homo sapiens_hsa03015
#  [10] Basal transcription factors_Homo sapiens_hsa03022
#  [11] Thyroid hormone signaling pathway_Homo sapiens_hsa04919
#  [12] Hypertrophic cardiomyopathy (HCM)_Homo sapiens_hsa05410
#  [13] Shigellosis_Homo sapiens_hsa05131
#  [14] Notch signaling pathway_Homo sapiens_hsa04330
#  [15] Neurotrophin signaling pathway_Homo sapiens_hsa04722
#  [16] Phagosome_Homo sapiens_hsa04145
#  [17] Ribosome_Homo sapiens_hsa03010
#  [18] Arginine and proline metabolism_Homo sapiens_hsa00330
#  [19] Purine metabolism_Homo sapiens_hsa00230
#  [20] Transcriptional misregulation in cancer_Homo sapiens_hsa05202
#  [21] Salmonella infection_Homo sapiens_hsa05132
#  [22] Dilated cardiomyopathy_Homo sapiens_hsa05414
#  [23] Chronic myeloid leukemia_Homo sapiens_hsa05220
#  [24] Alzheimer's disease_Homo sapiens_hsa05010
#  [25] SNARE interactions in vesicular transport_Homo sapiens_hsa04130
#  [26] Rap1 signaling pathway_Homo sapiens_hsa04015
#  [27] Legionellosis_Homo sapiens_hsa05134
#  [28] African trypanosomiasis_Homo sapiens_hsa05143
#  [29] Pancreatic secretion_Homo sapiens_hsa04972
#  [30] Apoptosis_Homo sapiens_hsa04210
#  [31] Amoebiasis_Homo sapiens_hsa05146
#  [32] Tuberculosis_Homo sapiens_hsa05152
#  [33] Calcium signaling pathway_Homo sapiens_hsa04020
#  [34] Oocyte meiosis_Homo sapiens_hsa04114
#  [35] Cell cycle_Homo sapiens_hsa04110
#  [36] Protein processing in endoplasmic reticulum_Homo sapiens_hsa04141
#  [37] Inflammatory bowel disease (IBD)_Homo sapiens_hsa05321
#  [38] Small cell lung cancer_Homo sapiens_hsa05222
#  [39] Retinol metabolism_Homo sapiens_hsa00830
#  [40] TNF signaling pathway_Homo sapiens_hsa04668
#  [41] Huntington's disease_Homo sapiens_hsa05016
#  [42] Type I diabetes mellitus_Homo sapiens_hsa04940
#  [43] HTLV-I infection_Homo sapiens_hsa05166
#  [44] Vasopressin-regulated water reabsorption_Homo sapiens_hsa04962
#  [45] Hippo signaling pathway_Homo sapiens_hsa04390
#  [46] Fc gamma R-mediated phagocytosis_Homo sapiens_hsa04666
#  [47] Insulin signaling pathway_Homo sapiens_hsa04910
#  [48] Inflammatory mediator regulation of TRP channels_Homo sapiens_hsa04750
#  [49] Leukocyte transendothelial migration_Homo sapiens_hsa04670
#  [50] RIG-I-like receptor signaling pathway_Homo sapiens_hsa04622
#  [51] Leishmaniasis_Homo sapiens_hsa05140
#  [52] AGE-RAGE signaling pathway in diabetic complications_Homo sapiens_hsa04933
#  [53] Melanogenesis_Homo sapiens_hsa04916
#  [54] Olfactory transduction_Homo sapiens_hsa04740
#  [55] PI3K-Akt signaling pathway_Homo sapiens_hsa04151
#  [56] Jak-STAT signaling pathway_Homo sapiens_hsa04630
#  [57] Phospholipase D signaling pathway_Homo sapiens_hsa04072
#  [58] HIF-1 signaling pathway_Homo sapiens_hsa04066
#  [59] Retrograde endocannabinoid signaling_Homo sapiens_hsa04723
#  [60] Osteoclast differentiation_Homo sapiens_hsa04380
#  [61] Glucagon signaling pathway_Homo sapiens_hsa04922
#  [62] GABAergic synapse_Homo sapiens_hsa04727
#  [63] RNA degradation_Homo sapiens_hsa03018
#  [64] Taste transduction_Homo sapiens_hsa04742
#  [65] Peroxisome_Homo sapiens_hsa04146
#  [66] Chemical carcinogenesis_Homo sapiens_hsa05204
#  [67] Adrenergic signaling in cardiomyocytes_Homo sapiens_hsa04261
#  [68] Epstein-Barr virus infection_Homo sapiens_hsa05169
#  [69] Proteoglycans in cancer_Homo sapiens_hsa05205
#  [70] Cell adhesion molecules (CAMs)_Homo sapiens_hsa04514
#  [71] Serotonergic synapse_Homo sapiens_hsa04726
#  [72] Endocytosis_Homo sapiens_hsa04144
#  [73] Complement and coagulation cascades_Homo sapiens_hsa04610
#  [74] Ras signaling pathway_Homo sapiens_hsa04014
#  [75] Cholinergic synapse_Homo sapiens_hsa04725
#  [76] cAMP signaling pathway_Homo sapiens_hsa04024
#  [77] Neuroactive ligand-receptor interaction_Homo sapiens_hsa04080
#  [78] Chagas disease (American trypanosomiasis)_Homo sapiens_hsa05142
#  [79] Pertussis_Homo sapiens_hsa05133
#  [80] Antigen processing and presentation_Homo sapiens_hsa04612
#  [81] Toll-like receptor signaling pathway_Homo sapiens_hsa04620
#  [82] Natural killer cell mediated cytotoxicity_Homo sapiens_hsa04650
#  [83] Systemic lupus erythematosus_Homo sapiens_hsa05322
#  [84] FoxO signaling pathway_Homo sapiens_hsa04068
#  [85] Hepatitis C_Homo sapiens_hsa05160
#  [86] Choline metabolism in cancer_Homo sapiens_hsa05231
#  [87] Melanoma_Homo sapiens_hsa05218
#  [88] Influenza A_Homo sapiens_hsa05164
#  [89] Insulin resistance_Homo sapiens_hsa04931
#  [90] Bacterial invasion of epithelial cells_Homo sapiens_hsa05100
#  [91] Lysosome_Homo sapiens_hsa04142
#  [92] Fc epsilon RI signaling pathway_Homo sapiens_hsa04664
#  [93] Central carbon metabolism in cancer_Homo sapiens_hsa05230
#  [94] Aldosterone synthesis and secretion_Homo sapiens_hsa04925
#  [95] Focal adhesion_Homo sapiens_hsa04510
#  [96] Type II diabetes mellitus_Homo sapiens_hsa04930
#  [97] Longevity regulating pathway - mammal_Homo sapiens_hsa04211
#  [98] Sphingolipid signaling pathway_Homo sapiens_hsa04071
#  [99] Pathways in cancer_Homo sapiens_hsa05200
# [100] Cocaine addiction_Homo sapiens_hsa05030
# [101] Aminoacyl-tRNA biosynthesis_Homo sapiens_hsa00970
# [102] cGMP-PKG signaling pathway_Homo sapiens_hsa04022
# [103] Synaptic vesicle cycle_Homo sapiens_hsa04721
# [104] Oxidative phosphorylation_Homo sapiens_hsa00190
# [105] ErbB signaling pathway_Homo sapiens_hsa04012
# [106] Measles_Homo sapiens_hsa05162
# [107] Oxytocin signaling pathway_Homo sapiens_hsa04921
# [108] VEGF signaling pathway_Homo sapiens_hsa04370
# [109] mTOR signaling pathway_Homo sapiens_hsa04150
# [110] Long-term depression_Homo sapiens_hsa04730
# [111] Vibrio cholerae infection_Homo sapiens_hsa05110
# [112] Insulin secretion_Homo sapiens_hsa04911
# [113] Metabolic pathways_Homo sapiens_hsa01100
# [114] Amyotrophic lateral sclerosis (ALS)_Homo sapiens_hsa05014
# [115] Viral carcinogenesis_Homo sapiens_hsa05203
# [116] Carbon metabolism_Homo sapiens_hsa01200
# [117] Herpes simplex infection_Homo sapiens_hsa05168
# [118] Glycerolipid metabolism_Homo sapiens_hsa00561
# [119] Hematopoietic cell lineage_Homo sapiens_hsa04640
# [120] Glycosaminoglycan degradation_Homo sapiens_hsa00531
# [121] Wnt signaling pathway_Homo sapiens_hsa04310
# [122] Cytokine-cytokine receptor interaction_Homo sapiens_hsa04060
# [123] Prostate cancer_Homo sapiens_hsa05215
# [124] N-Glycan biosynthesis_Homo sapiens_hsa00510
# [125] Axon guidance_Homo sapiens_hsa04360
# [126] MicroRNAs in cancer_Homo sapiens_hsa05206
# [127] MAPK signaling pathway_Homo sapiens_hsa04010
# [128] GnRH signaling pathway_Homo sapiens_hsa04912
# [129] RNA transport_Homo sapiens_hsa03013
# [130] Parkinson's disease_Homo sapiens_hsa05012
# [131] Acute myeloid leukemia_Homo sapiens_hsa05221
# [132] Regulation of actin cytoskeleton_Homo sapiens_hsa04810
# [133] AMPK signaling pathway_Homo sapiens_hsa04152
# [134] Hepatitis B_Homo sapiens_hsa05161
# [135] Salivary secretion_Homo sapiens_hsa04970
# [136] Ubiquitin mediated proteolysis_Homo sapiens_hsa04120
# [137] Signaling pathways regulating pluripotency of stem cells_Homo sapiens_hsa04550
# [138] Chemokine signaling pathway_Homo sapiens_hsa04062
# [139] Non-alcoholic fatty liver disease (NAFLD)_Homo sapiens_hsa04932
# [140] Cardiac muscle contraction_Homo sapiens_hsa04260
# [141] Spliceosome_Homo sapiens_hsa03040
# [142] Alcoholism_Homo sapiens_hsa05034
# [143] Platelet activation_Homo sapiens_hsa04611
# [144] NF-kappa B signaling pathway_Homo sapiens_hsa04064
# [145] Glutamatergic synapse_Homo sapiens_hsa04724
# [146] Endometrial cancer_Homo sapiens_hsa05213
# [147] Vascular smooth muscle contraction_Homo sapiens_hsa04270
# [148] Toxoplasmosis_Homo sapiens_hsa05145
# [149] Glycerophospholipid metabolism_Homo sapiens_hsa00564
# [150] Dopaminergic synapse_Homo sapiens_hsa04728
# [151] Autoimmune thyroid disease_Homo sapiens_hsa05320
# [152] Circadian entrainment_Homo sapiens_hsa04713
# [153] Viral myocarditis_Homo sapiens_hsa05416
# [154] Progesterone-mediated oocyte maturation_Homo sapiens_hsa04914
# [155] T cell receptor signaling pathway_Homo sapiens_hsa04660
# [156] Estrogen signaling pathway_Homo sapiens_hsa04915
# [157] Pyrimidine metabolism_Homo sapiens_hsa00240
# [158] Glutathione metabolism_Homo sapiens_hsa00480
# [159] Phosphatidylinositol signaling system_Homo sapiens_hsa04070
# [160] Rheumatoid arthritis_Homo sapiens_hsa05323
# [161] Metabolism of xenobiotics by cytochrome P450_Homo sapiens_hsa00980
# [162] Pancreatic cancer_Homo sapiens_hsa05212
# [163] Gap junction_Homo sapiens_hsa04540
# [164] Renin secretion_Homo sapiens_hsa04924
# [165] Ribosome biogenesis in eukaryotes_Homo sapiens_hsa03008
# [166] Protein digestion and absorption_Homo sapiens_hsa04974
# [167] Malaria_Homo sapiens_hsa05144
# [168] TGF-beta signaling pathway_Homo sapiens_hsa04350
# [169] Adipocytokine signaling pathway_Homo sapiens_hsa04920
# [170] B cell receptor signaling pathway_Homo sapiens_hsa04662
# [171] ECM-receptor interaction_Homo sapiens_hsa04512
# [172] Fatty acid metabolism_Homo sapiens_hsa01212
# [173] Prolactin signaling pathway_Homo sapiens_hsa04917
# [174] p53 signaling pathway_Homo sapiens_hsa04115
# [175] Biosynthesis of amino acids_Homo sapiens_hsa01230
# [176] Inositol phosphate metabolism_Homo sapiens_hsa00562
# [177] Bile secretion_Homo sapiens_hsa04976
# [178] Adherens junction_Homo sapiens_hsa04520
# [179] Renal cell carcinoma_Homo sapiens_hsa05211
# [180] Arachidonic acid metabolism_Homo sapiens_hsa00590
# [181] Gastric acid secretion_Homo sapiens_hsa04971
# [182] Epithelial cell signaling in Helicobacter pylori infection_Homo sapiens_hsa05120
# [183] Nucleotide excision repair_Homo sapiens_hsa03420
# [184] Thyroid cancer_Homo sapiens_hsa05216
# [185] Thyroid hormone synthesis_Homo sapiens_hsa04918
# [186] Sphingolipid metabolism_Homo sapiens_hsa00600
# [187] Glycolysis / Gluconeogenesis_Homo sapiens_hsa00010
# [188] Glioma_Homo sapiens_hsa05214
# [189] Longevity regulating pathway - multiple species_Homo sapiens_hsa04213
# [190] Cytosolic DNA-sensing pathway_Homo sapiens_hsa04623
# [191] Ether lipid metabolism_Homo sapiens_hsa00565
# [192] Maturity onset diabetes of the young_Homo sapiens_hsa04950
# [193] Colorectal cancer_Homo sapiens_hsa05210
# [194] Linoleic acid metabolism_Homo sapiens_hsa00591
# [195] NOD-like receptor signaling pathway_Homo sapiens_hsa04621
# [196] Steroid hormone biosynthesis_Homo sapiens_hsa00140
# [197] Non-small cell lung cancer_Homo sapiens_hsa05223
# [198] Pathogenic Escherichia coli infection_Homo sapiens_hsa05130
# [199] Basal cell carcinoma_Homo sapiens_hsa05217
# [200] Fat digestion and absorption_Homo sapiens_hsa04975
# [201] Graft-versus-host disease_Homo sapiens_hsa05332
# [202] Nicotine addiction_Homo sapiens_hsa05033
# [203] Bladder cancer_Homo sapiens_hsa05219
# [204] Ovarian steroidogenesis_Homo sapiens_hsa04913
# [205] Lysine degradation_Homo sapiens_hsa00310
# [206] Endocrine and other factor-regulated calcium reabsorption_Homo sapiens_hsa04961
# [207] Terpenoid backbone biosynthesis_Homo sapiens_hsa00900
# [208] Allograft rejection_Homo sapiens_hsa05330
# [209] Amino sugar and nucleotide sugar metabolism_Homo sapiens_hsa00520
# [210] Drug metabolism - other enzymes_Homo sapiens_hsa00983
# [211] ABC transporters_Homo sapiens_hsa02010
# [212] Primary immunodeficiency_Homo sapiens_hsa05340
# [213] Proteasome_Homo sapiens_hsa03050
# [214] Cysteine and methionine metabolism_Homo sapiens_hsa00270
# [215] Tryptophan metabolism_Homo sapiens_hsa00380
# [216] Fructose and mannose metabolism_Homo sapiens_hsa00051
# [217] Glycine, serine and threonine metabolism_Homo sapiens_hsa00260
# [218] Regulation of autophagy_Homo sapiens_hsa04140
# [219] Pyruvate metabolism_Homo sapiens_hsa00620
# ...
#  [63] Calcium signaling pathway_Homo sapiens_hsa04020
#  [64] Adrenergic signaling in cardiomyocytes_Homo sapiens_hsa04261
#  [65] Cysteine and methionine metabolism_Homo sapiens_hsa00270
#  [66] Phospholipase D signaling pathway_Homo sapiens_hsa04072
#  [67] Serotonergic synapse_Homo sapiens_hsa04726
#  [68] Cholinergic synapse_Homo sapiens_hsa04725
#  [69] Complement and coagulation cascades_Homo sapiens_hsa04610
#  [70] Insulin signaling pathway_Homo sapiens_hsa04910
#  [71] Antigen processing and presentation_Homo sapiens_hsa04612
#  [72] Valine, leucine and isoleucine degradation_Homo sapiens_hsa00280
#  [73] Toll-like receptor signaling pathway_Homo sapiens_hsa04620
#  [74] Pertussis_Homo sapiens_hsa05133
#  [75] Systemic lupus erythematosus_Homo sapiens_hsa05322
#  [76] FoxO signaling pathway_Homo sapiens_hsa04068
#  [77] Amino sugar and nucleotide sugar metabolism_Homo sapiens_hsa00520
#  [78] Proteasome_Homo sapiens_hsa03050
#  [79] Prolactin signaling pathway_Homo sapiens_hsa04917
#  [80] Oxytocin signaling pathway_Homo sapiens_hsa04921
#  [81] Bile secretion_Homo sapiens_hsa04976
#  [82] Retrograde endocannabinoid signaling_Homo sapiens_hsa04723
#  [83] Estrogen signaling pathway_Homo sapiens_hsa04915
#  [84] Fc epsilon RI signaling pathway_Homo sapiens_hsa04664
#  [85] Purine metabolism_Homo sapiens_hsa00230
#  [86] Viral carcinogenesis_Homo sapiens_hsa05203
#  [87] Proteoglycans in cancer_Homo sapiens_hsa05205
#  [88] Sphingolipid signaling pathway_Homo sapiens_hsa04071
#  [89] TNF signaling pathway_Homo sapiens_hsa04668
#  [90] mTOR signaling pathway_Homo sapiens_hsa04150
#  [91] Retinol metabolism_Homo sapiens_hsa00830
#  [92] HTLV-I infection_Homo sapiens_hsa05166
#  [93] Thyroid hormone signaling pathway_Homo sapiens_hsa04919
#  [94] Inflammatory bowel disease (IBD)_Homo sapiens_hsa05321
#  [95] Morphine addiction_Homo sapiens_hsa05032
#  [96] Cytokine-cytokine receptor interaction_Homo sapiens_hsa04060
#  [97] cGMP-PKG signaling pathway_Homo sapiens_hsa04022
#  [98] Rap1 signaling pathway_Homo sapiens_hsa04015
#  [99] ErbB signaling pathway_Homo sapiens_hsa04012
# [100] Chemokine signaling pathway_Homo sapiens_hsa04062
# [101] Measles_Homo sapiens_hsa05162
# [102] Pathways in cancer_Homo sapiens_hsa05200
# [103] Osteoclast differentiation_Homo sapiens_hsa04380
# [104] Insulin secretion_Homo sapiens_hsa04911
# [105] Fatty acid elongation_Homo sapiens_hsa00062
# [106] Small cell lung cancer_Homo sapiens_hsa05222
# [107] PI3K-Akt signaling pathway_Homo sapiens_hsa04151
# [108] Chemical carcinogenesis_Homo sapiens_hsa05204
# [109] Chagas disease (American trypanosomiasis)_Homo sapiens_hsa05142
# [110] NOD-like receptor signaling pathway_Homo sapiens_hsa04621
# [111] Tight junction_Homo sapiens_hsa04530
# [112] Staphylococcus aureus infection_Homo sapiens_hsa05150
# [113] Rheumatoid arthritis_Homo sapiens_hsa05323
# [114] Amoebiasis_Homo sapiens_hsa05146
# [115] Signaling pathways regulating pluripotency of stem cells_Homo sapiens_hsa04550
# [116] Bacterial invasion of epithelial cells_Homo sapiens_hsa05100
# [117] RNA transport_Homo sapiens_hsa03013
# [118] Neurotrophin signaling pathway_Homo sapiens_hsa04722
# [119] Hepatitis B_Homo sapiens_hsa05161
# [120] Cardiac muscle contraction_Homo sapiens_hsa04260
# [121] MAPK signaling pathway_Homo sapiens_hsa04010
# [122] Vascular smooth muscle contraction_Homo sapiens_hsa04270
# [123] Epstein-Barr virus infection_Homo sapiens_hsa05169
# [124] Lysosome_Homo sapiens_hsa04142
# [125] Herpes simplex infection_Homo sapiens_hsa05168
# [126] Ras signaling pathway_Homo sapiens_hsa04014
# [127] Tuberculosis_Homo sapiens_hsa05152
# [128] AMPK signaling pathway_Homo sapiens_hsa04152
# [129] Longevity regulating pathway - mammal_Homo sapiens_hsa04211
# [130] Circadian entrainment_Homo sapiens_hsa04713
# [131] Endometrial cancer_Homo sapiens_hsa05213
# [132] Longevity regulating pathway - multiple species_Homo sapiens_hsa04213
# [133] Influenza A_Homo sapiens_hsa05164
# [134] Glycerophospholipid metabolism_Homo sapiens_hsa00564
# [135] Phagosome_Homo sapiens_hsa04145
# [136] Cell cycle_Homo sapiens_hsa04110
# [137] B cell receptor signaling pathway_Homo sapiens_hsa04662
# [138] Hepatitis C_Homo sapiens_hsa05160
# [139] Fanconi anemia pathway_Homo sapiens_hsa03460
# [140] NF-kappa B signaling pathway_Homo sapiens_hsa04064
# [141] Insulin resistance_Homo sapiens_hsa04931
# [142] AGE-RAGE signaling pathway in diabetic complications_Homo sapiens_hsa04933
# [143] Metabolism of xenobiotics by cytochrome P450_Homo sapiens_hsa00980
# [144] Arrhythmogenic right ventricular cardiomyopathy (ARVC)_Homo sapiens_hsa05412
# [145] Lysine degradation_Homo sapiens_hsa00310
# [146] Axon guidance_Homo sapiens_hsa04360
# [147] Amyotrophic lateral sclerosis (ALS)_Homo sapiens_hsa05014
# [148] Melanoma_Homo sapiens_hsa05218
# [149] T cell receptor signaling pathway_Homo sapiens_hsa04660
# [150] Choline metabolism in cancer_Homo sapiens_hsa05231
# [151] Glucagon signaling pathway_Homo sapiens_hsa04922
# [152] Central carbon metabolism in cancer_Homo sapiens_hsa05230
# [153] Dilated cardiomyopathy_Homo sapiens_hsa05414
# [154] Mismatch repair_Homo sapiens_hsa03430
# [155] Ovarian steroidogenesis_Homo sapiens_hsa04913
# [156] Malaria_Homo sapiens_hsa05144
# [157] Chronic myeloid leukemia_Homo sapiens_hsa05220
# [158] Glycosylphosphatidylinositol(GPI)-anchor biosynthesis_Homo sapiens_hsa00563
# [159] p53 signaling pathway_Homo sapiens_hsa04115
# [160] Terpenoid backbone biosynthesis_Homo sapiens_hsa00900
# [161] Salmonella infection_Homo sapiens_hsa05132
# [162] Intestinal immune network for IgA production_Homo sapiens_hsa04672
# [163] Synaptic vesicle cycle_Homo sapiens_hsa04721
# [164] Leishmaniasis_Homo sapiens_hsa05140
# [165] ECM-receptor interaction_Homo sapiens_hsa04512
# [166] Prostate cancer_Homo sapiens_hsa05215
# [167] Shigellosis_Homo sapiens_hsa05131
# [168] Epithelial cell signaling in Helicobacter pylori infection_Homo sapiens_hsa05120
# [169] Hematopoietic cell lineage_Homo sapiens_hsa04640
# [170] RNA degradation_Homo sapiens_hsa03018
# [171] TGF-beta signaling pathway_Homo sapiens_hsa04350
# [172] RIG-I-like receptor signaling pathway_Homo sapiens_hsa04622
# [173] Hypertrophic cardiomyopathy (HCM)_Homo sapiens_hsa05410
# [174] Ribosome biogenesis in eukaryotes_Homo sapiens_hsa03008
# [175] Cytosolic DNA-sensing pathway_Homo sapiens_hsa04623
# [176] Adherens junction_Homo sapiens_hsa04520
# [177] Vasopressin-regulated water reabsorption_Homo sapiens_hsa04962
# [178] Pentose phosphate pathway_Homo sapiens_hsa00030
# [179] Colorectal cancer_Homo sapiens_hsa05210
# [180] Regulation of lipolysis in adipocytes_Homo sapiens_hsa04923
# [181] Glycerolipid metabolism_Homo sapiens_hsa00561
# [182] Fat digestion and absorption_Homo sapiens_hsa04975
# [183] Glioma_Homo sapiens_hsa05214
# [184] Non-small cell lung cancer_Homo sapiens_hsa05223
# [185] Pathogenic Escherichia coli infection_Homo sapiens_hsa05130
# [186] VEGF signaling pathway_Homo sapiens_hsa04370
# [187] Tryptophan metabolism_Homo sapiens_hsa00380
# [188] Starch and sucrose metabolism_Homo sapiens_hsa00500
# [189] Acute myeloid leukemia_Homo sapiens_hsa05221
# [190] Carbohydrate digestion and absorption_Homo sapiens_hsa04973
# [191] Homologous recombination_Homo sapiens_hsa03440
# [192] Basal transcription factors_Homo sapiens_hsa03022
# [193] Other types of O-glycan biosynthesis_Homo sapiens_hsa00514
# [194] Legionellosis_Homo sapiens_hsa05134
# [195] Regulation of autophagy_Homo sapiens_hsa04140
# [196] Propanoate metabolism_Homo sapiens_hsa00640
# [197] Vibrio cholerae infection_Homo sapiens_hsa05110
# [198] Fructose and mannose metabolism_Homo sapiens_hsa00051
# [199] Arachidonic acid metabolism_Homo sapiens_hsa00590
# [200] Arginine and proline metabolism_Homo sapiens_hsa00330
# [201] Prion diseases_Homo sapiens_hsa05020
# [202] ABC transporters_Homo sapiens_hsa02010
# [203] Notch signaling pathway_Homo sapiens_hsa04330
# [204] Glutathione metabolism_Homo sapiens_hsa00480
# [205] Nucleotide excision repair_Homo sapiens_hsa03420
# [206] Type II diabetes mellitus_Homo sapiens_hsa04930
# [207] Tyrosine metabolism_Homo sapiens_hsa00350
# [208] Sphingolipid metabolism_Homo sapiens_hsa00600
# [209] Ether lipid metabolism_Homo sapiens_hsa00565
# [210] Thyroid cancer_Homo sapiens_hsa05216
# [211] Bladder cancer_Homo sapiens_hsa05219
# [212] Base excision repair_Homo sapiens_hsa03410
# [213] Alanine, aspartate and glutamate metabolism_Homo sapiens_hsa00250
# [214] Linoleic acid metabolism_Homo sapiens_hsa00591
# [215] Mucin type O-Glycan biosynthesis_Homo sapiens_hsa00512
# [216] SNARE interactions in vesicular transport_Homo sapiens_hsa04130
# [217] Glyoxylate and dicarboxylate metabolism_Homo sapiens_hsa00630
# [218] Nicotinate and nicotinamide metabolism_Homo sapiens_hsa00760
# [219] Glycine, serine and threonine metabolism_Homo sapiens_hsa00260
# [220] Circadian rhythm_Homo sapiens_hsa04710
# [221] Phototransduction_Homo sapiens_hsa04744
# [222] alpha-Linolenic acid metabolism_Homo sapiens_hsa00592
# [223] Collecting duct acid secretion_Homo sapiens_hsa04966
# [224] Pentose and glucuronate interconversions_Homo sapiens_hsa00040
# [225] Maturity onset diabetes of the young_Homo sapiens_hsa04950
# [226] Glycosaminoglycan biosynthesis - heparan sulfate / heparin_Homo sapiens_hsa00534
# [227] Citrate cycle (TCA cycle)_Homo sapiens_hsa00020
# [228] Proximal tubule bicarbonate reclamation_Homo sapiens_hsa04964
# [229] Protein export_Homo sapiens_hsa03060
# [230] Butanoate metabolism_Homo sapiens_hsa00650
# [231] Steroid biosynthesis_Homo sapiens_hsa00100
# [232] 2-Oxocarboxylic acid metabolism_Homo sapiens_hsa01210
# [233] One carbon pool by folate_Homo sapiens_hsa00670
# [234] Fatty acid biosynthesis_Homo sapiens_hsa00061
# [235] Phenylalanine metabolism_Homo sapiens_hsa00360
# [236] Primary bile acid biosynthesis_Homo sapiens_hsa00120
# [237] Nitrogen metabolism_Homo sapiens_hsa00910
# [238] Arginine biosynthesis_Homo sapiens_hsa00220
# [239] Glycosphingolipid biosynthesis - globo series_Homo sapiens_hsa00603
# [240] Glycosphingolipid biosynthesis - ganglio series_Homo sapiens_hsa00604
# [241] Non-homologous end-joining_Homo sapiens_hsa03450
# [242] Synthesis and degradation of ketone bodies_Homo sapiens_hsa00072
# [243] Sulfur metabolism_Homo sapiens_hsa00920
# [244] Phenylalanine, tyrosine and tryptophan biosynthesis_Homo sapiens_hsa00400
# [245] Butirosin and neomycin biosynthesis_Homo sapiens_hsa00524
# 245 Levels: 2-Oxocarboxylic acid metabolism_Homo sapiens_hsa01210 ...

# %% [markdown]
# ## Combining results from both streams.

# %%
## Combining Enrichr KEGG and GO results

enrichr_results_shredded <- list()
length(enrichr_results_shredded) <- length (enrichr_go_terms_extracted_results_shredded)
names(enrichr_results_shredded) <- names (enrichr_go_terms_extracted_results_shredded)

for (i in 1:length(enrichr_results_shredded))
{
  if(names(enrichr_results_shredded) == names(enrichr_go_terms_extracted_results_shredded) && names(enrichr_results_shredded) == names(enrichr_kegg_terms_extracted_results_shredded))
  {
    enrichr_results_shredded[[i]] <- rbind(enrichr_go_terms_extracted_results_shredded[[i]], enrichr_kegg_terms_extracted_results_shredded[[i]], stringsAsFactors = FALSE)
  }
}
# Out:
# Warning message in `[<-.factor`(`*tmp*`, ri, value = c(0.000575402920313306, 0.0277515150464923, :
# “invalid factor level, NA generated”

# %%
class(enrichr_results_shredded)
# Out:
# [1] "list"

# %%
class(enrichr_results_shredded[[1]])
# Out:
# [1] "data.frame"

# %%
class(enrichr_results_shredded[[1]]$Term)
# Out:
# [1] "character"

# %%
class(enrichr_results_shredded[[1]]$P.value)
# Out:
# [1] "numeric"

# %% [markdown]
# There is hence an articulation between the different objects in the results. The **enrichr_results_shredded** is the list holding enrichment results from both KEGG and GO ontologies for each sample. In the downstream analysis, it will be required to compare with the actual terms in the disease pools and so the positioning is important from the perspective of ranks and prioritization calculations. To accomplish that an ordering by ascendance is warranted.

# %%
## Sorting on the basis of "P.value"

for (i in 1:length(enrichr_results_shredded))
{
  enrichr_results_shredded[[i]] <- enrichr_results_shredded[[i]][with(enrichr_results_shredded[[i]], order(enrichr_results_shredded[[i]]$P.value)), ] 
}
# Out:
# Error in order(...): argument 1 is not a vector
# Traceback:
#
# 1. with(enrichr_results_shredded[[i]], order(enrichr_results_shredded[[i]]$P.value))
# 2. with(enrichr_results_shredded[[i]], order(enrichr_results_shredded[[i]]$P.value))
# 3. with.default(enrichr_results_shredded[[i]], order(enrichr_results_shredded[[i]]$P.value))
# 4. eval(substitute(expr), data, enclos = parent.frame())
# 5. eval(substitute(expr), data, enclos = parent.frame())
# 6. order(enrichr_results_shredded[[i]]$P.value)
# 7. standardGeneric("order")
# 8. eval(mc, env)
# 9. eval(mc, env)
# 10. eval(mc, env)
# 11. order(...)
